# %%
import csv
with open('hrishipara_financial_diaries.csv') as var_name:
    reader=csv.reader(var_name)
    A = [row for row in reader]
import pingouin as pg
import numpy as np
import pandas as pd

df = pd.DataFrame(A)
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header
df['code']=df['code'].str.upper()
df['description']=df['description'].str.lower()
df["takaout"] = pd.to_numeric(df["takaout"])
df["takain"] = pd.to_numeric(df["takain"])
dfo=df.groupby([pd.Grouper(key='date',freq='M'),'description'])['takaout'].sum().unstack()
dfo.replace(0, np.nan, inplace=True)
dfo=dfo.dropna(axis=1, how="all")
dfi=df.groupby([pd.Grouper(key='date',freq='M'),'description'])['takain'].sum().unstack()
dfi.replace(0, np.nan, inplace=True)
dfi=dfi.dropna(axis=1, how="all")
dfx= pd.concat([dfi, dfo], axis=1)
dfx
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-525b1e0ecdd3> in <module>
#      15 df["takaout"] = pd.to_numeric(df["takaout"])
#      16 df["takain"] = pd.to_numeric(df["takain"])
# ---> 17 dfo=df.groupby([pd.Grouper(key='date',freq='M'),'description'])['takaout'].sum().unstack()
#      18 dfo.replace(0, np.nan, inplace=True)
#      19 dfo=dfo.dropna(axis=1, how="all")
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ...

# %%
dfx.head()
# Out:
# 0        date       ref   code class                 description  \
# 1  2015-05-20  descript  02OBM   IRI             rickshaw income
# 2  2015-05-20  descript  01KIF   IWA               earned income
# 3  2015-05-20    no rec  01KIF   IWA               earned income
# 4  2015-05-20    no rec  01KIF   ETE  snacks, treats, stimulants
# 5  2015-05-20    no rec  01KIF   ETR             transport costs
#
# 0          subclass     tag takain takaout         details  \
# 1  rickshaw driving      bb    260       0       rickshaw
# 2       shop labour  no rec     40       0  vegetable shop
# 3       shop labour  no rec     10       0  vegetable shop
# 4   betel nut, leaf  no rec      0      -5       betel nut
# 5             ferry  no rec      0      -4            boat
#
# 0                                              notes flow         type  \
# 1  Rickshaw driving 02obm is 35, rickshaw driver,...   in       income
# 2  Wages 01kif , widow, 45. One person hh (she ha...   in       income
# ...
