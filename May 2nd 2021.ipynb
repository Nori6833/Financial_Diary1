# %%
import csv
with open('hrishipara_financial_diaries.csv') as var_name:
    reader=csv.reader(var_name)
    A = [row for row in reader]

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

df = pd.DataFrame(A)
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header
df['code']=df['code'].str.upper()
df['description']=df['description'].str.lower()
df5= df.drop(df[(df.code!="05RAF")].index)
df5['date']=pd.to_datetime(df5.date)
df5["takaout"] = pd.to_numeric(df5["takaout"])
df5["takain"] = pd.to_numeric(df5["takain"])
df["takaout"] = pd.to_numeric(df["takaout"])
df["takain"] = pd.to_numeric(df["takain"])

# %%
df5o=df5.groupby([pd.Grouper(key='date',freq='M'),'description'])['takaout'].sum().unstack()
df5o.replace(0, np.nan, inplace=True)
df5o=df5o.dropna(axis=1, how="all")
df5o
# Out:
# description  clothes, cloth  communications  education costs  fees paid  \
# date
# 2015-08-31          -1130.0          -195.0          -2150.0        NaN
# 2015-09-30           -200.0             NaN            -50.0        NaN
# 2015-10-31              NaN             NaN           -100.0        NaN
# 2015-11-30              NaN           -10.0          -1110.0        NaN
# 2015-12-31              NaN             NaN           -100.0        NaN
# ...                     ...             ...              ...        ...
# 2020-10-31              NaN          -210.0              NaN        NaN
# 2020-11-30              NaN             NaN              NaN        NaN
# 2020-12-31              NaN             NaN              NaN        NaN
# 2021-01-31              NaN             NaN              NaN        NaN
# 2021-02-28              NaN             NaN              NaN        NaN
#
# description  food costs  fuel costs  gifts to outsiders  healthcare costs  \
# date
# ...

# %%
df5i=df5.groupby([pd.Grouper(key='date',freq='M'),'description'])['takain'].sum().unstack()
df5i.replace(0, np.nan, inplace=True)
df5i=df5i.dropna(axis=1, how="all")
df5i
# Out:
# description  earned income  gifts from outsiders  home or street snack sales  \
# date
# 2015-08-31             NaN                5175.0                         NaN
# 2015-09-30             NaN                 700.0                         NaN
# 2015-10-31             NaN                 100.0                         NaN
# 2015-11-30             NaN                1100.0                         NaN
# 2015-12-31             NaN                1400.0                         NaN
# ...                    ...                   ...                         ...
# 2020-10-31           200.0                   NaN                         NaN
# 2020-11-30           800.0                   NaN                         NaN
# 2020-12-31             NaN                   NaN                         NaN
# 2021-01-31             NaN                 100.0                         NaN
# 2021-02-28          2400.0                   NaN                         NaN
#
# ...

# %%
df5x= pd.concat([df5i, df5o], axis=1)
df5x
# Out:
# description  earned income  gifts from outsiders  home or street snack sales  \
# date
# 2015-08-31             NaN                5175.0                         NaN
# 2015-09-30             NaN                 700.0                         NaN
# 2015-10-31             NaN                 100.0                         NaN
# 2015-11-30             NaN                1100.0                         NaN
# 2015-12-31             NaN                1400.0                         NaN
# ...                    ...                   ...                         ...
# 2020-10-31           200.0                   NaN                         NaN
# 2020-11-30           800.0                   NaN                         NaN
# 2020-12-31             NaN                   NaN                         NaN
# 2021-01-31             NaN                 100.0                         NaN
# 2021-02-28          2400.0                   NaN                         NaN
#
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt


corrMatrix = df5x.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
df5o.plot.bar(y=['home maintenance'], alpha=0.6, figsize=(12,3))
plt.title(u'Home construction_by Month', size=16)
# Out:
# Text(0.5, 1.0, 'Home construction_by Month')

# %%
df52= df.drop(df[(df.code!="52KBY")].index)
df52['date']=pd.to_datetime(df52.date)
df52["takaout"] = pd.to_numeric(df52["takaout"])
df52["takain"] = pd.to_numeric(df52["takain"])
df52o=df52.groupby([pd.Grouper(key='date',freq='M'),'description'])['takaout'].sum().unstack()
df52o.replace(0, np.nan, inplace=True)
df52o=df52o.dropna(axis=1, how="all")
df52o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 44 entries, 2017-07-31 to 2021-02-28
# Freq: M
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   business asset purchase     1 non-null      float64
#  1   clothes, cloth              1 non-null      float64
#  2   farm inputs                 1 non-null      float64
#  3   fees paid                   3 non-null      float64
#  4   food costs                  44 non-null     float64
#  5   fuel costs                  24 non-null     float64
#  6   gifts to outsiders          3 non-null      float64
#  7   healthcare costs            15 non-null     float64
#  8   home construction           3 non-null      float64
#  9   home maintenance            16 non-null     float64
#  10  loan or howlat given        1 non-null      float64
#  11  loan repayment made         42 non-null     float64
# ...

# %%
df52o.plot.bar(y=['home construction','home maintenance'], alpha=0.6, figsize=(12,3))
plt.title(u'52KBY Home construction_by Month', size=16)
# Out:
# Text(0.5, 1.0, '52KBY Home construction_by Month')

# %%
df52o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 44 entries, 2017-07-31 to 2021-02-28
# Freq: M
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Food costs                  6 non-null      float64
#  1   Fuel costs                  2 non-null      float64
#  2   Healthcare costs            1 non-null      float64
#  3   Loan repayment made         7 non-null      float64
#  4   Savings deposited           7 non-null      float64
#  5   Shop stock purchases        7 non-null      float64
#  6   Snacks, treats, stimulants  1 non-null      float64
#  7   Toiletries purchased        2 non-null      float64
#  8   Transport costs             3 non-null      float64
#  9   Utilities cost              4 non-null      float64
#  10  business asset purchase     1 non-null      float64
#  11  clothes, cloth              1 non-null      float64
# ...

# %%
df['description']
# Out:
# 1                    rickshaw income
# 2                      earned income
# 3                      earned income
# 4         snacks, treats, stimulants
# 5                    transport costs
#                      ...
# 940294                    shop sales
# 940295                    shop sales
# 940296                    shop sales
# 940297                    shop sales
# 940298                    shop sales
# Name: description, Length: 940298, dtype: object

# %%
from scipy import stats
corr_df=pd.DataFrame(columns=['r','p'])
for col0 in df5x:
    for col in df5x:
        if pd.api.types.is_numeric_dtype(df5x[col]):
            r,p = stats.pearsonr(df5x[col0], df5x[col])

            corr_df.loc[col]=[round(r,3),round(p,3)]

corr_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-bf8b35c6276c> in <module>
#       4     for col in df5x:
#       5         if pd.api.types.is_numeric_dtype(df5x[col]):
# ----> 6             r,p = stats.pearsonr(df5x[col0], df5x[col])
#       7
#       8             corr_df.loc[col]=[round(r,3),round(p,3)]
#
# ~\miniconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3933     # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    3934     # [-5e210, 5e210, 3e200, -3e200]
# -> 3935     normxm = linalg.norm(xm)
#    3936     normym = linalg.norm(ym)
#    3937
#
# ~\miniconda3\lib\site-packages\scipy\linalg\misc.py in norm(a, ord, axis, keepdims, check_finite)
#     138     # Differs from numpy only in non-finite handling and the use of blas.
#     139     if check_finite:
# --> 140         a = np.asarray_chkfinite(a)
# ...

# %%
df5x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 67 entries, 2015-08-31 to 2021-02-28
# Freq: M
# Data columns (total 38 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   earned income                    28 non-null     float64
#  1   gifts from outsiders             38 non-null     float64
#  2   home or street snack sales       3 non-null      float64
#  3   loan or howlat taken             20 non-null     float64
#  4   loan taken from diary project    5 non-null      float64
#  5   other income                     29 non-null     float64
#  6   payment from diary project       67 non-null     float64
#  7   payments received                1 non-null      float64
#  8   recycling income                 1 non-null      float64
#  9   savings accepted from others     1 non-null      float64
#  10  savings withdrawal taken         10 non-null     float64
# ...

# %%
df5x.corr()
# Out:
# description                      earned income  gifts from outsiders  \
# description
# earned income                         1.000000              0.383649
# gifts from outsiders                  0.383649              1.000000
# home or street snack sales                 NaN                   NaN
# loan or howlat taken                  0.114615             -0.244509
# loan taken from diary project              NaN              0.807025
# other income                         -0.211114             -0.211087
# payment from diary project                 NaN              0.484073
# payments received                          NaN                   NaN
# recycling income                           NaN                   NaN
# savings accepted from others               NaN                   NaN
# savings withdrawal taken                   NaN              0.943899
# shop sales                            0.035917              0.281907
# ...

# %%
df5d=df5.groupby([pd.Grouper(key='date',freq='D'),'description'])['takaout'].sum().unstack()
df5d.replace(0, np.nan, inplace=True)
df5d=df5d.dropna(axis=1, how="all")
df5d.fillna(0, inplace=True)
df5d
# Out:
# description  clothes, cloth  communications  education costs  fees paid  \
# date
# 2015-08-02              0.0             0.0          -2150.0        0.0
# 2015-08-03              0.0             0.0              0.0        0.0
# 2015-08-04              0.0             0.0              0.0        0.0
# 2015-08-05              0.0           -10.0              0.0        0.0
# 2015-08-06              0.0           -10.0              0.0        0.0
# ...                     ...             ...              ...        ...
# 2021-02-24              0.0             0.0              0.0        0.0
# 2021-02-25              0.0             0.0              0.0        0.0
# 2021-02-26              0.0             0.0              0.0        0.0
# 2021-02-27              0.0             0.0              0.0        0.0
# 2021-02-28              0.0             0.0              0.0        0.0
#
# description  food costs  fuel costs  gifts to outsiders  healthcare costs  \
# date
# ...

# %%
from scipy import stats
corr_df=pd.DataFrame(columns=['r','p'])
for col0 in df5d:
    for col in df5d:
        if pd.api.types.is_numeric_dtype(df5d[col]):
            r,p = stats.pearsonr(df5d[col0], df5d[col])

            corr_df.loc[col0,col]=[round(r,3),round(p,3)]

corr_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-8ec6dbfa39e6> in <module>
#       6             r,p = stats.pearsonr(df5d[col0], df5d[col])
#       7
# ----> 8             corr_df.loc[col0,col]=[round(r,3),round(p,3)]
#       9
#      10 corr_df
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1602                             indexer, self.obj.axes
#    1603                         )
# -> 1604                         self._setitem_with_indexer(new_indexer, value, name)
#    1605
# ...
